# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import csv
import os

# %% [markdown]
# # Data Cleaning and File Conversions

# %%
# Convert countries text file to csv

import csv
import os


def parse_countries_file(input_path, output_path):
    """
    Parse the GHCND countries file and convert it to CSV format.

    Args:
        input_path (str): Path to the input ghcnd-countries.txt file
        output_path (str): Path to save the output CSV file
    """
    # Create the output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    countries_data = []

    # Read and parse the input file
    with open(input_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():  # Skip empty lines
                code = line[0:2].strip()
                name = line[3:].strip()
                countries_data.append([code, name])

    # Write to CSV file
    with open(output_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["code", "name"])  # Write header
        writer.writerows(countries_data)


input_file = "data/climate/ghcnd-countries.txt"
output_file = "data/climate/ghcnd-countries.csv"


parse_countries_file(input_file, output_file)
print(f"Successfully converted {input_file} to {output_file}")
# Out:
# Successfully converted data/climate/ghcnd-countries.txt to data/climate/ghcnd-countries.csv

# %%
# Convert states text file to csv
def parse_states_file(input_path, output_path):
    """
    Parse the GHCND states file and convert it to CSV format.

    Args:
        input_path (str): Path to the input ghcnd-states.txt file
        output_path (str): Path to save the output CSV file
    """
    # Create the output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    states_data = []

    # Read and parse the input file
    with open(input_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():  # Skip empty lines
                code = line[0:2].strip()
                name = line[3:].strip()
                states_data.append([code, name])

    # Write to CSV file
    with open(output_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["code", "name"])  # Write header
        writer.writerows(states_data)
input_file = "data/climate/ghcnd-states.txt"
output_file = "data/climate/ghcnd-states.csv"
parse_states_file(input_file, output_file)
print(f"Successfully converted {input_file} to {output_file}")
# Out:
# Successfully converted data/climate/ghcnd-states.txt to data/climate/ghcnd-states.csv

# %%
def parse_inventory_file(input_path, output_path):
    """
    Parse the GHCND inventory file and convert it to CSV format.

    Args:
        input_path (str): Path to the input ghcnd-inventory.txt file
        output_path (str): Path to save the output CSV file
    """
    # Create the output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    inventory_data = []

    # Read and parse the input file
    with open(input_path, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():  # Skip empty lines
                # Parse fixed-width fields
                station_id = line[0:11].strip()
                latitude = float(line[12:20].strip())
                longitude = float(line[21:30].strip())
                element = line[31:35].strip()
                first_year = int(line[36:40].strip())
                last_year = int(line[41:45].strip())
                
                inventory_data.append([station_id, latitude, longitude, element, first_year, last_year])

    # Write to CSV file
    with open(output_file, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["id", "latitude", "longitude", "element", "first_year", "last_year"])  # Write header
        writer.writerows(inventory_data)

parse_inventory_file(input_file, output_file)
print(f"Successfully converted {input_file} to {output_file}")
# Out:
# Successfully converted data/climate/ghcnd-inventory.txt to data/climate/ghcnd-inventory.csv

# %%
import pandas as pd


def parse_dly_line(line):
    """
    Parse one line from a GHCN-Daily .dly file.

    Each line has fixed-width columns:
      - Columns 1-11: Station ID
      - Columns 12-15: Year
      - Columns 16-17: Month
      - Columns 18-21: Element
      - Then for each day (1 to 31):
          * Columns 22-26, 30-34, ...: Value (integer, -9999 if missing)
          * Next column: Measurement flag (MFLAG)
          * Next column: Quality flag (QFLAG)
          * Next column: Source flag (SFLAG)

    Returns a dictionary with parsed data.
    """
    record = {}
    record["id"] = line[0:11]
    record["year"] = int(line[11:15])
    record["month"] = int(line[15:17])
    record["element"] = line[17:21]

    daily_values = []
    # Each day occupies 8 characters starting at column 22 (index 21)
    for day in range(31):
        start = 21 + day * 8
        value_str = line[start : start + 5]
        try:
            value = int(value_str)
        except ValueError:
            value = None

        mflag = line[start + 5]
        qflag = line[start + 6]
        sflag = line[start + 7]

        # A value of -9999 is considered missing
        if value == -9999:
            value = None

        daily_values.append(
            {
                "day": day + 1,
                "value": value,
                "mflag": mflag.strip() or None,
                "qflag": qflag.strip() or None,
                "sflag": sflag.strip() or None,
            }
        )

    record["daily_values"] = daily_values
    return record


def parse_dly_file(filename):
    """
    Parse a GHCN-Daily .dly file.

    Returns a list of dictionaries, one per record (month) in the file.
    """
    records = []
    with open(filename, "r") as f:
        for line in f:
            # Ensure the line has enough characters to be a valid record
            if len(line) < 269:
                continue
            record = parse_dly_line(line)
            records.append(record)
    return records


def dly_to_dataframe(filename):
    """
    Convert the parsed .dly file into a pandas DataFrame.

    Each row represents a single day's observation.
    """
    records = parse_dly_file(filename)
    rows = []
    for rec in records:
        station_id = rec["id"]
        year = rec["year"]
        month = rec["month"]
        element = rec["element"]
        for day_rec in rec["daily_values"]:
            row = {
                "station_id": station_id,
                "year": year,
                "month": month,
                "day": day_rec["day"],
                "element": element,
                "value": day_rec["value"],
                "mflag": day_rec["mflag"],
                "qflag": day_rec["qflag"],
                "sflag": day_rec["sflag"],
            }
            rows.append(row)
    df = pd.DataFrame(rows)
    return df


input_file = "data/climate/ghcnd_all/ASN00086135.dly"
output_csv = "data/climate/ghcnd_all_csv/ASN00086135.csv"

# Create DataFrame from the .dly file.
df = dly_to_dataframe(input_file)

# Export DataFrame to CSV.
df.to_csv(output_csv, index=False)
print(f"Exported DataFrame to {output_csv}")

# %%
# Convert all .dly files in a directory to CSV
def convert_all_dly_to_csv(input_dir, output_dir):
    """
    Convert all .dly files in the input directory to CSV format.

    Args:
        input_dir (str): Path to the input directory containing .dly files
        output_dir (str): Path to the output directory for CSV files
    """
    os.makedirs(output_dir, exist_ok=True)

    for filename in os.listdir(input_dir):
        if filename.endswith(".dly"):
            dly_path = os.path.join(input_dir, filename)
            csv_path = os.path.join(output_dir, filename.replace(".dly", ".csv"))
            df = dly_to_dataframe(dly_path)
            df.to_csv(csv_path, index=False)
            print(f"Converted {filename} to {csv_path}")

input_dir = "data/climate/ghcnd_all"
output_dir = "data/climate/ghcnd_all_csv"
convert_all_dly_to_csv(input_dir, output_dir)
# Out:
# Converted AM000037959.dly to data/climate/ghcnd_all_csv/AM000037959.csv
# Converted IN012230800.dly to data/climate/ghcnd_all_csv/IN012230800.csv
# Converted IN011070700.dly to data/climate/ghcnd_all_csv/IN011070700.csv
# Converted CA004011580.dly to data/climate/ghcnd_all_csv/CA004011580.csv
# Converted CA004077605.dly to data/climate/ghcnd_all_csv/CA004077605.csv
# Converted ASN00080010.dly to data/climate/ghcnd_all_csv/ASN00080010.csv
# Converted MXN00008057.dly to data/climate/ghcnd_all_csv/MXN00008057.csv
# Converted AM000037781.dly to data/climate/ghcnd_all_csv/AM000037781.csv
# Converted IN020100301.dly to data/climate/ghcnd_all_csv/IN020100301.csv
# Converted KZ000038333.dly to data/climate/ghcnd_all_csv/KZ000038333.csv
# Converted ASN00014103.dly to data/climate/ghcnd_all_csv/ASN00014103.csv
# Converted BR028815040.dly to data/climate/ghcnd_all_csv/BR028815040.csv
# Converted ASN00085168.dly to data/climate/ghcnd_all_csv/ASN00085168.csv
# Converted CA007063320.dly to data/climate/ghcnd_all_csv/CA007063320.csv
# Converted IN011410203.dly to data/climate/ghcnd_all_csv/IN011410203.csv
# Converted ASN00046123.dly to data/climate/ghcnd_all_csv/ASN00046123.csv
# Converted ASN00059003.dly to data/climate/ghcnd_all_csv/ASN00059003.csv
# Converted GQW00041414.dly to data/climate/ghcnd_all_csv/GQW00041414.csv
# Converted ASN00040552.dly to data/climate/ghcnd_all_csv/ASN00040552.csv
# Converted CA1ON000476.dly to data/climate/ghcnd_all_csv/CA1ON000476.csv
# Converted BR00D9-0010.dly to data/climate/ghcnd_all_csv/BR00D9-0010.csv
# Converted ASN00009634.dly to data/climate/ghcnd_all_csv/ASN00009634.csv
# Converted MXN00003102.dly to data/climate/ghcnd_all_csv/MXN00003102.csv
# Converted CA006131983.dly to data/climate/ghcnd_all_csv/CA006131983.csv
# Converted ASN00050027.dly to data/climate/ghcnd_all_csv/ASN00050027.csv
# Converted BF1SS000006.dly to data/climate/ghcnd_all_csv/BF1SS000006.csv
# Converted ASN00039091.dly to data/climate/ghcnd_all_csv/ASN00039091.csv
# Converted CA001196543.dly to data/climate/ghcnd_all_csv/CA001196543.csv
# Converted ASN00016072.dly to data/climate/ghcnd_all_csv/ASN00016072.csv
# Converted MXN00014318.dly to data/climate/ghcnd_all_csv/MXN00014318.csv
# Converted ASN00040234.dly to data/climate/ghcnd_all_csv/ASN00040234.csv
# Converted CA003011241.dly to data/climate/ghcnd_all_csv/CA003011241.csv
# Converted CA1ON000310.dly to data/climate/ghcnd_all_csv/CA1ON000310.csv
# Converted IN004050100.dly to data/climate/ghcnd_all_csv/IN004050100.csv
# Converted ASN00009152.dly to data/climate/ghcnd_all_csv/ASN00009152.csv
# Converted CA003051665.dly to data/climate/ghcnd_all_csv/CA003051665.csv
# Converted BR001137041.dly to data/climate/ghcnd_all_csv/BR001137041.csv
# Converted MXN00015006.dly to data/climate/ghcnd_all_csv/MXN00015006.csv
# Converted CA006127887.dly to data/climate/ghcnd_all_csv/CA006127887.csv
# Converted CA001183628.dly to data/climate/ghcnd_all_csv/CA001183628.csv
# Converted CA003012990.dly to data/climate/ghcnd_all_csv/CA003012990.csv
# Converted ASN00089034.dly to data/climate/ghcnd_all_csv/ASN00089034.csv
# Converted MXN00001073.dly to data/climate/ghcnd_all_csv/MXN00001073.csv
# Converted ASN00086307.dly to data/climate/ghcnd_all_csv/ASN00086307.csv
# Converted IN023150700.dly to data/climate/ghcnd_all_csv/IN023150700.csv
# Converted GME00131422.dly to data/climate/ghcnd_all_csv/GME00131422.csv
# Converted ASN00012214.dly to data/climate/ghcnd_all_csv/ASN00012214.csv
# Converted ASN00074191.dly to data/climate/ghcnd_all_csv/ASN00074191.csv
# Converted ASN00002007.dly to data/climate/ghcnd_all_csv/ASN00002007.csv
# Converted ASN00044052.dly to data/climate/ghcnd_all_csv/ASN00044052.csv
# Converted CA006114295.dly to data/climate/ghcnd_all_csv/CA006114295.csv
# Converted ASN00087019.dly to data/climate/ghcnd_all_csv/ASN00087019.csv
# Converted ASN00089020.dly to data/climate/ghcnd_all_csv/ASN00089020.csv
# Converted BR001344017.dly to data/climate/ghcnd_all_csv/BR001344017.csv
# Converted ASN00086313.dly to data/climate/ghcnd_all_csv/ASN00086313.csv
# Converted ASN00012200.dly to data/climate/ghcnd_all_csv/ASN00012200.csv
# Converted RSM00029789.dly to data/climate/ghcnd_all_csv/RSM00029789.csv
# Converted BR038335880.dly to data/climate/ghcnd_all_csv/BR038335880.csv
# Converted ASN00074185.dly to data/climate/ghcnd_all_csv/ASN00074185.csv
# Converted ASN00044046.dly to data/climate/ghcnd_all_csv/ASN00044046.csv
# Converted ASN00002013.dly to data/climate/ghcnd_all_csv/ASN00002013.csv
# Converted CA007028123.dly to data/climate/ghcnd_all_csv/CA007028123.csv
# Converted BR00D8-0010.dly to data/climate/ghcnd_all_csv/BR00D8-0010.csv
# Converted ASN00016066.dly to data/climate/ghcnd_all_csv/ASN00016066.csv
# Converted ASN00039085.dly to data/climate/ghcnd_all_csv/ASN00039085.csv
# Converted BF1SS000012.dly to data/climate/ghcnd_all_csv/BF1SS000012.csv
# Converted ASN00050033.dly to data/climate/ghcnd_all_csv/ASN00050033.csv
# Converted LYE00147743.dly to data/climate/ghcnd_all_csv/LYE00147743.csv
# Converted ASN00040220.dly to data/climate/ghcnd_all_csv/ASN00040220.csv
# Converted HUE00100247.dly to data/climate/ghcnd_all_csv/HUE00100247.csv
# Converted ASN00009146.dly to data/climate/ghcnd_all_csv/ASN00009146.csv
# Converted IN017030900.dly to data/climate/ghcnd_all_csv/IN017030900.csv
# Converted ASN00008258.dly to data/climate/ghcnd_all_csv/ASN00008258.csv
# Converted MXN00015012.dly to data/climate/ghcnd_all_csv/MXN00015012.csv
# Converted BR000446000.dly to data/climate/ghcnd_all_csv/BR000446000.csv
# Converted BR026588720.dly to data/climate/ghcnd_all_csv/BR026588720.csv
# Converted IN023050700.dly to data/climate/ghcnd_all_csv/IN023050700.csv
# Converted ASN00059017.dly to data/climate/ghcnd_all_csv/ASN00059017.csv
# Converted CA004023240.dly to data/climate/ghcnd_all_csv/CA004023240.csv
# Converted ARM00087643.dly to data/climate/ghcnd_all_csv/ARM00087643.csv
# Converted MXN00099028.dly to data/climate/ghcnd_all_csv/MXN00099028.csv
# Converted ASN00094071.dly to data/climate/ghcnd_all_csv/ASN00094071.csv
# Converted CA008205698.dly to data/climate/ghcnd_all_csv/CA008205698.csv
# Converted ASN00009620.dly to data/climate/ghcnd_all_csv/ASN00009620.csv
# Converted CA1ON000462.dly to data/climate/ghcnd_all_csv/CA1ON000462.csv
# Converted GME00123754.dly to data/climate/ghcnd_all_csv/GME00123754.csv
# Converted MXN00003116.dly to data/climate/ghcnd_all_csv/MXN00003116.csv
# Converted NOE00157084.dly to data/climate/ghcnd_all_csv/NOE00157084.csv
# Converted IN004150100.dly to data/climate/ghcnd_all_csv/IN004150100.csv
# Converted IN009194800.dly to data/climate/ghcnd_all_csv/IN009194800.csv
# Converted MXN00007370.dly to data/climate/ghcnd_all_csv/MXN00007370.csv
# Converted ASN00080004.dly to data/climate/ghcnd_all_csv/ASN00080004.csv
# Converted ASN00062081.dly to data/climate/ghcnd_all_csv/ASN00062081.csv
# Converted CA006068148.dly to data/climate/ghcnd_all_csv/CA006068148.csv
# Converted GME00131350.dly to data/climate/ghcnd_all_csv/GME00131350.csv
# Converted RSM00031878.dly to data/climate/ghcnd_all_csv/RSM00031878.csv
# Converted RQC00661623.dly to data/climate/ghcnd_all_csv/RQC00661623.csv
# Converted ASN00091109.dly to data/climate/ghcnd_all_csv/ASN00091109.csv
# Converted CA00810D9KN.dly to data/climate/ghcnd_all_csv/CA00810D9KN.csv
# Converted FIE00144087.dly to data/climate/ghcnd_all_csv/FIE00144087.csv
# Converted ASN00030089.dly to data/climate/ghcnd_all_csv/ASN00030089.csv
# Converted ASN00011047.dly to data/climate/ghcnd_all_csv/ASN00011047.csv
# Converted ASN00009608.dly to data/climate/ghcnd_all_csv/ASN00009608.csv
# Converted ASN00057012.dly to data/climate/ghcnd_all_csv/ASN00057012.csv
# Converted BR028946430.dly to data/climate/ghcnd_all_csv/BR028946430.csv
# Converted ASN00094059.dly to data/climate/ghcnd_all_csv/ASN00094059.csv
# Converted IN009162600.dly to data/climate/ghcnd_all_csv/IN009162600.csv
# Converted BR00C5-0370.dly to data/climate/ghcnd_all_csv/BR00C5-0370.csv
# Converted ASN00048132.dly to data/climate/ghcnd_all_csv/ASN00048132.csv
# Converted IN005150201.dly to data/climate/ghcnd_all_csv/IN005150201.csv
# Converted ASN00043067.dly to data/climate/ghcnd_all_csv/ASN00043067.csv
# Converted ASN00005032.dly to data/climate/ghcnd_all_csv/ASN00005032.csv
# Converted MXN00027088.dly to data/climate/ghcnd_all_csv/MXN00027088.csv
# Converted GME00130066.dly to data/climate/ghcnd_all_csv/GME00130066.csv
# Converted MXN00007358.dly to data/climate/ghcnd_all_csv/MXN00007358.csv
# Converted NLE00101989.dly to data/climate/ghcnd_all_csv/NLE00101989.csv
# Converted ASN00023793.dly to data/climate/ghcnd_all_csv/ASN00023793.csv
# Converted MXN00019166.dly to data/climate/ghcnd_all_csv/MXN00019166.csv
# Converted ASN00091121.dly to data/climate/ghcnd_all_csv/ASN00091121.csv
# Converted MXN00016255.dly to data/climate/ghcnd_all_csv/MXN00016255.csv
# Converted ASN00089008.dly to data/climate/ghcnd_all_csv/ASN00089008.csv
# Converted ASN00055163.dly to data/climate/ghcnd_all_csv/ASN00055163.csv
# Converted MXN00010142.dly to data/climate/ghcnd_all_csv/MXN00010142.csv
# Converted ASN00012228.dly to data/climate/ghcnd_all_csv/ASN00012228.csv
# Converted MXN00030292.dly to data/climate/ghcnd_all_csv/MXN00030292.csv
# Converted BGM00041936.dly to data/climate/ghcnd_all_csv/BGM00041936.csv
# Converted CA003012774.dly to data/climate/ghcnd_all_csv/CA003012774.csv
# Converted ASN00015547.dly to data/climate/ghcnd_all_csv/ASN00015547.csv
# Converted CA003075937.dly to data/climate/ghcnd_all_csv/CA003075937.csv
# Converted ASN00087025.dly to data/climate/ghcnd_all_csv/ASN00087025.csv
# Converted MXN00020081.dly to data/climate/ghcnd_all_csv/MXN00020081.csv
# Converted MXN00014324.dly to data/climate/ghcnd_all_csv/MXN00014324.csv
# Converted ASN00093050.dly to data/climate/ghcnd_all_csv/ASN00093050.csv
# Converted FIE00142390.dly to data/climate/ghcnd_all_csv/FIE00142390.csv
# Converted CA008100770.dly to data/climate/ghcnd_all_csv/CA008100770.csv
# Converted ASN00040208.dly to data/climate/ghcnd_all_csv/ASN00040208.csv
# Converted ASN00041116.dly to data/climate/ghcnd_all_csv/ASN00041116.csv
# Converted ASN00007143.dly to data/climate/ghcnd_all_csv/ASN00007143.csv
# Converted MD000033678.dly to data/climate/ghcnd_all_csv/MD000033678.csv
# Converted ASN00018063.dly to data/climate/ghcnd_all_csv/ASN00018063.csv
# Converted IN020051600.dly to data/climate/ghcnd_all_csv/IN020051600.csv
# Converted ASN00093044.dly to data/climate/ghcnd_all_csv/ASN00093044.csv
# Converted MXN00014330.dly to data/climate/ghcnd_all_csv/MXN00014330.csv
# Converted CA1ON001026.dly to data/climate/ghcnd_all_csv/CA1ON001026.csv
# Converted ASN00082149.dly to data/climate/ghcnd_all_csv/ASN00082149.csv
# Converted ASN00008264.dly to data/climate/ghcnd_all_csv/ASN00008264.csv
# Converted ASN00007157.dly to data/climate/ghcnd_all_csv/ASN00007157.csv
# Converted ASN00041102.dly to data/climate/ghcnd_all_csv/ASN00041102.csv
# Converted ASN00018077.dly to data/climate/ghcnd_all_csv/ASN00018077.csv
# Converted ASN00037094.dly to data/climate/ghcnd_all_csv/ASN00037094.csv
# Converted IN008010801.dly to data/climate/ghcnd_all_csv/IN008010801.csv
# Converted CA006139449.dly to data/climate/ghcnd_all_csv/CA006139449.csv
# Converted FIE00141855.dly to data/climate/ghcnd_all_csv/FIE00141855.csv
# Converted IN018120400.dly to data/climate/ghcnd_all_csv/IN018120400.csv
# Converted ASN00055177.dly to data/climate/ghcnd_all_csv/ASN00055177.csv
# Converted GME00130714.dly to data/climate/ghcnd_all_csv/GME00130714.csv
# Converted CA003012760.dly to data/climate/ghcnd_all_csv/CA003012760.csv
# Converted IN009062600.dly to data/climate/ghcnd_all_csv/IN009062600.csv
# Converted CA00307A954.dly to data/climate/ghcnd_all_csv/CA00307A954.csv
# Converted BR00C4-0370.dly to data/climate/ghcnd_all_csv/BR00C4-0370.csv
# Converted ASN00087031.dly to data/climate/ghcnd_all_csv/ASN00087031.csv
# Converted ASN00015553.dly to data/climate/ghcnd_all_csv/ASN00015553.csv
# Converted MXN00020095.dly to data/climate/ghcnd_all_csv/MXN00020095.csv
# Converted CA007010480.dly to data/climate/ghcnd_all_csv/CA007010480.csv
# Converted CA003064190.dly to data/climate/ghcnd_all_csv/CA003064190.csv
# Converted ASN00005026.dly to data/climate/ghcnd_all_csv/ASN00005026.csv
# Converted ASN00043073.dly to data/climate/ghcnd_all_csv/ASN00043073.csv
# Converted IN023440900.dly to data/climate/ghcnd_all_csv/IN023440900.csv
# Converted ASN00080038.dly to data/climate/ghcnd_all_csv/ASN00080038.csv
# Converted CA001167592.dly to data/climate/ghcnd_all_csv/CA001167592.csv
# Converted CA001063086.dly to data/climate/ghcnd_all_csv/CA001063086.csv
# Converted MXN00006052.dly to data/climate/ghcnd_all_csv/MXN00006052.csv
# Converted GME00126610.dly to data/climate/ghcnd_all_csv/GME00126610.csv
# Converted MXN00019172.dly to data/climate/ghcnd_all_csv/MXN00019172.csv
# Converted ASN00023787.dly to data/climate/ghcnd_all_csv/ASN00023787.csv
# Converted CA001106178.dly to data/climate/ghcnd_all_csv/CA001106178.csv
# Converted MXN00016241.dly to data/climate/ghcnd_all_csv/MXN00016241.csv
# Converted ASN00091135.dly to data/climate/ghcnd_all_csv/ASN00091135.csv
# Converted RQC00662316.dly to data/climate/ghcnd_all_csv/RQC00662316.csv
# Converted BR038693240.dly to data/climate/ghcnd_all_csv/BR038693240.csv
# Converted ASN00085140.dly to data/climate/ghcnd_all_csv/ASN00085140.csv
# Converted BR003252024.dly to data/climate/ghcnd_all_csv/BR003252024.csv
# Converted MXN00012027.dly to data/climate/ghcnd_all_csv/MXN00012027.csv
# Converted ASN00057006.dly to data/climate/ghcnd_all_csv/ASN00057006.csv
# Converted ASN00011053.dly to data/climate/ghcnd_all_csv/ASN00011053.csv
# Converted MXN00099014.dly to data/climate/ghcnd_all_csv/MXN00099014.csv
# Converted ASN00048126.dly to data/climate/ghcnd_all_csv/ASN00048126.csv
# Converted BR036995960.dly to data/climate/ghcnd_all_csv/BR036995960.csv
# Converted CA003077661.dly to data/climate/ghcnd_all_csv/CA003077661.csv
# Converted HUM00012772.dly to data/climate/ghcnd_all_csv/HUM00012772.csv
# Converted AR000087860.dly to data/climate/ghcnd_all_csv/AR000087860.csv
# Converted NLE00152490.dly to data/climate/ghcnd_all_csv/NLE00152490.csv
# Converted ASN00069103.dly to data/climate/ghcnd_all_csv/ASN00069103.csv
# Converted BR001946011.dly to data/climate/ghcnd_all_csv/BR001946011.csv
# Converted ASN00076023.dly to data/climate/ghcnd_all_csv/ASN00076023.csv
# Converted ASN00030076.dly to data/climate/ghcnd_all_csv/ASN00030076.csv
# Converted FIE00143717.dly to data/climate/ghcnd_all_csv/FIE00143717.csv
# Converted RSM00028326.dly to data/climate/ghcnd_all_csv/RSM00028326.csv
# Converted ASN00024003.dly to data/climate/ghcnd_all_csv/ASN00024003.csv
# Converted ASN00062056.dly to data/climate/ghcnd_all_csv/ASN00062056.csv
# Converted CGM00064206.dly to data/climate/ghcnd_all_csv/CGM00064206.csv
# Converted CA003072719.dly to data/climate/ghcnd_all_csv/CA003072719.csv
# Converted MXN00019199.dly to data/climate/ghcnd_all_csv/MXN00019199.csv
# Converted CA008501100.dly to data/climate/ghcnd_all_csv/CA008501100.csv
# Converted BR038415710.dly to data/climate/ghcnd_all_csv/BR038415710.csv
# Converted GB000004507.dly to data/climate/ghcnd_all_csv/GB000004507.csv
# Converted RSM00031677.dly to data/climate/ghcnd_all_csv/RSM00031677.csv
# Converted IN017100800.dly to data/climate/ghcnd_all_csv/IN017100800.csv
# Converted BR008361005.dly to data/climate/ghcnd_all_csv/BR008361005.csv
# Converted CA006104723.dly to data/climate/ghcnd_all_csv/CA006104723.csv
# Converted MXN00008094.dly to data/climate/ghcnd_all_csv/MXN00008094.csv
# Converted IN012200900.dly to data/climate/ghcnd_all_csv/IN012200900.csv
# Converted MXN00027077.dly to data/climate/ghcnd_all_csv/MXN00027077.csv
# Converted IN010011000.dly to data/climate/ghcnd_all_csv/IN010011000.csv
# Converted ASN00043098.dly to data/climate/ghcnd_all_csv/ASN00043098.csv
# Converted CA1SK000156.dly to data/climate/ghcnd_all_csv/CA1SK000156.csv
# Converted IN012010201.dly to data/climate/ghcnd_all_csv/IN012010201.csv
# Converted ASN00074152.dly to data/climate/ghcnd_all_csv/ASN00074152.csv
# Converted ASN00032107.dly to data/climate/ghcnd_all_csv/ASN00032107.csv
# Converted ASN00044091.dly to data/climate/ghcnd_all_csv/ASN00044091.csv
# Converted CA007057720.dly to data/climate/ghcnd_all_csv/CA007057720.csv
# Converted BR001846005.dly to data/climate/ghcnd_all_csv/BR001846005.csv
# Converted RSM00028440.dly to data/climate/ghcnd_all_csv/RSM00028440.csv
# Converted ASN00033219.dly to data/climate/ghcnd_all_csv/ASN00033219.csv
# Converted ASN00061239.dly to data/climate/ghcnd_all_csv/ASN00061239.csv
# Converted GME00125494.dly to data/climate/ghcnd_all_csv/GME00125494.csv
# Converted KG000038471.dly to data/climate/ghcnd_all_csv/KG000038471.csv
# Converted FIE00143071.dly to data/climate/ghcnd_all_csv/FIE00143071.csv
# Converted IN010091600.dly to data/climate/ghcnd_all_csv/IN010091600.csv
# Converted BR048338870.dly to data/climate/ghcnd_all_csv/BR048338870.csv
# Converted RSM00034069.dly to data/climate/ghcnd_all_csv/RSM00034069.csv
# Converted BR001941018.dly to data/climate/ghcnd_all_csv/BR001941018.csv
# Converted BR002147035.dly to data/climate/ghcnd_all_csv/BR002147035.csv
# Converted ASN00039052.dly to data/climate/ghcnd_all_csv/ASN00039052.csv
# Converted BR038960060.dly to data/climate/ghcnd_all_csv/BR038960060.csv
# Converted ASN00070334.dly to data/climate/ghcnd_all_csv/ASN00070334.csv
# Converted BR00C8-0060.dly to data/climate/ghcnd_all_csv/BR00C8-0060.csv
# Converted ASN00009191.dly to data/climate/ghcnd_all_csv/ASN00009191.csv
# Converted ASN00060127.dly to data/climate/ghcnd_all_csv/ASN00060127.csv
# Converted MXN00025112.dly to data/climate/ghcnd_all_csv/MXN00025112.csv
# Converted COM00080315.dly to data/climate/ghcnd_all_csv/COM00080315.csv
# Converted CA004045660.dly to data/climate/ghcnd_all_csv/CA004045660.csv
# Converted BR001339017.dly to data/climate/ghcnd_all_csv/BR001339017.csv
# Converted ASN00018088.dly to data/climate/ghcnd_all_csv/ASN00018088.csv
# Converted ASN00039046.dly to data/climate/ghcnd_all_csv/ASN00039046.csv
# Converted IN011140600.dly to data/climate/ghcnd_all_csv/IN011140600.csv
# Converted MXN00030279.dly to data/climate/ghcnd_all_csv/MXN00030279.csv
# Converted ASN00074146.dly to data/climate/ghcnd_all_csv/ASN00074146.csv
# Converted RSM00026479.dly to data/climate/ghcnd_all_csv/RSM00026479.csv
# Converted ASN00044085.dly to data/climate/ghcnd_all_csv/ASN00044085.csv
# Converted CA006144475.dly to data/climate/ghcnd_all_csv/CA006144475.csv
# Converted ASN00055188.dly to data/climate/ghcnd_all_csv/ASN00055188.csv
# Converted IN012190401.dly to data/climate/ghcnd_all_csv/IN012190401.csv
# Converted NOE00109885.dly to data/climate/ghcnd_all_csv/NOE00109885.csv
# Converted ASN00024017.dly to data/climate/ghcnd_all_csv/ASN00024017.csv
# Converted BR001841018.dly to data/climate/ghcnd_all_csv/BR001841018.csv
# Converted CA005021965.dly to data/climate/ghcnd_all_csv/CA005021965.csv
# Converted CA005041049.dly to data/climate/ghcnd_all_csv/CA005041049.csv
# Converted ASN00023778.dly to data/climate/ghcnd_all_csv/ASN00023778.csv
# Converted RSM00037212.dly to data/climate/ghcnd_all_csv/RSM00037212.csv
# Converted BR00C9-0060.dly to data/climate/ghcnd_all_csv/BR00C9-0060.csv
# Converted MXM00076061.dly to data/climate/ghcnd_all_csv/MXM00076061.csv
# Converted CHM00054346.dly to data/climate/ghcnd_all_csv/CHM00054346.csv
# Converted CA007060826.dly to data/climate/ghcnd_all_csv/CA007060826.csv
# Converted MXN00027063.dly to data/climate/ghcnd_all_csv/MXN00027063.csv
# Converted MXN00008080.dly to data/climate/ghcnd_all_csv/MXN00008080.csv
# Converted IN003071800.dly to data/climate/ghcnd_all_csv/IN003071800.csv
# Converted BF1FP000007.dly to data/climate/ghcnd_all_csv/BF1FP000007.csv
# Converted ASN00040585.dly to data/climate/ghcnd_all_csv/ASN00040585.csv
# Converted CA008400578.dly to data/climate/ghcnd_all_csv/CA008400578.csv
# Converted IN012110201.dly to data/climate/ghcnd_all_csv/IN012110201.csv
# Converted FIE00145372.dly to data/climate/ghcnd_all_csv/FIE00145372.csv
# Converted ASN00068209.dly to data/climate/ghcnd_all_csv/ASN00068209.csv
# Converted CA1NS000239.dly to data/climate/ghcnd_all_csv/CA1NS000239.csv
# Converted NLE00152484.dly to data/climate/ghcnd_all_csv/NLE00152484.csv
# Converted CA001180490.dly to data/climate/ghcnd_all_csv/CA001180490.csv
# Converted BR047471110.dly to data/climate/ghcnd_all_csv/BR047471110.csv
# Converted RQ1PRGC0002.dly to data/climate/ghcnd_all_csv/RQ1PRGC0002.csv
# Converted ASN00030062.dly to data/climate/ghcnd_all_csv/ASN00030062.csv
# Converted BR038969050.dly to data/climate/ghcnd_all_csv/BR038969050.csv
# Converted ASN00076037.dly to data/climate/ghcnd_all_csv/ASN00076037.csv
# Converted BR001946005.dly to data/climate/ghcnd_all_csv/BR001946005.csv
# Converted IN018041001.dly to data/climate/ghcnd_all_csv/IN018041001.csv
# Converted IN019010601.dly to data/climate/ghcnd_all_csv/IN019010601.csv
# Converted RSM00030555.dly to data/climate/ghcnd_all_csv/RSM00030555.csv
# Converted CA005010548.dly to data/climate/ghcnd_all_csv/CA005010548.csv
# Converted IN020065200.dly to data/climate/ghcnd_all_csv/IN020065200.csv
# Converted CA00704DB9E.dly to data/climate/ghcnd_all_csv/CA00704DB9E.csv
# Converted ASN00023750.dly to data/climate/ghcnd_all_csv/ASN00023750.csv
# Converted FIE00146653.dly to data/climate/ghcnd_all_csv/FIE00146653.csv
# Converted ASN00035132.dly to data/climate/ghcnd_all_csv/ASN00035132.csv
# Converted BR001948000.dly to data/climate/ghcnd_all_csv/BR001948000.csv
# Converted CA008400550.dly to data/climate/ghcnd_all_csv/CA008400550.csv
# Converted CA003060321.dly to data/climate/ghcnd_all_csv/CA003060321.csv
# Converted CA1NS000211.dly to data/climate/ghcnd_all_csv/CA1NS000211.csv
# Converted FRE00171619.dly to data/climate/ghcnd_all_csv/FRE00171619.csv
# Converted IN012141700.dly to data/climate/ghcnd_all_csv/IN012141700.csv
# Converted ASN00067112.dly to data/climate/ghcnd_all_csv/ASN00067112.csv
# Converted AGE00147718.dly to data/climate/ghcnd_all_csv/AGE00147718.csv
# Converted CA001021262.dly to data/climate/ghcnd_all_csv/CA001021262.csv
# Converted ASN00009813.dly to data/climate/ghcnd_all_csv/ASN00009813.csv
# Converted BR047004750.dly to data/climate/ghcnd_all_csv/BR047004750.csv
# Converted CA007044760.dly to data/climate/ghcnd_all_csv/CA007044760.csv
# Converted CA006158712.dly to data/climate/ghcnd_all_csv/CA006158712.csv
# Converted BR002140000.dly to data/climate/ghcnd_all_csv/BR002140000.csv
# Converted ASN00061205.dly to data/climate/ghcnd_all_csv/ASN00061205.csv
# Converted CA008401128.dly to data/climate/ghcnd_all_csv/CA008401128.csv
# Converted IN020061700.dly to data/climate/ghcnd_all_csv/IN020061700.csv
# Converted ASN00007180.dly to data/climate/ghcnd_all_csv/ASN00007180.csv
# Converted ASN00037043.dly to data/climate/ghcnd_all_csv/ASN00037043.csv
# Converted CA007012240.dly to data/climate/ghcnd_all_csv/CA007012240.csv
# Converted FIE00144722.dly to data/climate/ghcnd_all_csv/FIE00144722.csv
# Converted CA008203564.dly to data/climate/ghcnd_all_csv/CA008203564.csv
# Converted IN009050103.dly to data/climate/ghcnd_all_csv/IN009050103.csv
# Converted BR00E3-0500.dly to data/climate/ghcnd_all_csv/BR00E3-0500.csv
# Converted BR00D4-0300.dly to data/climate/ghcnd_all_csv/BR00D4-0300.csv
# Converted ASN00070308.dly to data/climate/ghcnd_all_csv/ASN00070308.csv
# Converted CA005012439.dly to data/climate/ghcnd_all_csv/CA005012439.csv
# Converted BR00F3-0050.dly to data/climate/ghcnd_all_csv/BR00F3-0050.csv
# Converted BR002956008.dly to data/climate/ghcnd_all_csv/BR002956008.csv
# Converted BR057113650.dly to data/climate/ghcnd_all_csv/BR057113650.csv
# Converted IN018090300.dly to data/climate/ghcnd_all_csv/IN018090300.csv
# Converted KZ000028861.dly to data/climate/ghcnd_all_csv/KZ000028861.csv
# Converted ASN00015584.dly to data/climate/ghcnd_all_csv/ASN00015584.csv
# Converted KZ000036487.dly to data/climate/ghcnd_all_csv/KZ000036487.csv
# Converted MXN00020042.dly to data/climate/ghcnd_all_csv/MXN00020042.csv
# Converted IN001180702.dly to data/climate/ghcnd_all_csv/IN001180702.csv
# Converted ASN00023036.dly to data/climate/ghcnd_all_csv/ASN00023036.csv
# Converted BR001653005.dly to data/climate/ghcnd_all_csv/BR001653005.csv
# Converted BR002040014.dly to data/climate/ghcnd_all_csv/BR002040014.csv
# Converted CA005041707.dly to data/climate/ghcnd_all_csv/CA005041707.csv
# Converted ASN00033225.dly to data/climate/ghcnd_all_csv/ASN00033225.csv
# Converted IN013010100.dly to data/climate/ghcnd_all_csv/IN013010100.csv
# Converted CA004016562.dly to data/climate/ghcnd_all_csv/CA004016562.csv
# Converted ASN00014856.dly to data/climate/ghcnd_all_csv/ASN00014856.csv
# Converted CA002300750.dly to data/climate/ghcnd_all_csv/CA002300750.csv
# Converted MXN00030245.dly to data/climate/ghcnd_all_csv/MXN00030245.csv
# Converted ASN00015590.dly to data/climate/ghcnd_all_csv/ASN00015590.csv
# Converted BR001848000.dly to data/climate/ghcnd_all_csv/BR001848000.csv
# Converted RSM00027983.dly to data/climate/ghcnd_all_csv/RSM00027983.csv
# Converted BR048613180.dly to data/climate/ghcnd_all_csv/BR048613180.csv
# Converted FIE00146121.dly to data/climate/ghcnd_all_csv/FIE00146121.csv
# Converted MXN00020056.dly to data/climate/ghcnd_all_csv/MXN00020056.csv
# Converted CA001179009.dly to data/climate/ghcnd_all_csv/CA001179009.csv
# Converted ASN00023022.dly to data/climate/ghcnd_all_csv/ASN00023022.csv
# Converted MXN00001098.dly to data/climate/ghcnd_all_csv/MXN00001098.csv
# Converted BR002040000.dly to data/climate/ghcnd_all_csv/BR002040000.csv
# Converted ASN00033231.dly to data/climate/ghcnd_all_csv/ASN00033231.csv
# Converted GME00129286.dly to data/climate/ghcnd_all_csv/GME00129286.csv
# Converted CA001108828.dly to data/climate/ghcnd_all_csv/CA001108828.csv
# Converted CA003062244.dly to data/climate/ghcnd_all_csv/CA003062244.csv
# Converted CA001173242.dly to data/climate/ghcnd_all_csv/CA001173242.csv
# Converted ASN00061211.dly to data/climate/ghcnd_all_csv/ASN00061211.csv
# Converted ASN00007194.dly to data/climate/ghcnd_all_csv/ASN00007194.csv
# Converted ASN00037057.dly to data/climate/ghcnd_all_csv/ASN00037057.csv
# Converted CA008203570.dly to data/climate/ghcnd_all_csv/CA008203570.csv
# Converted CA003070640.dly to data/climate/ghcnd_all_csv/CA003070640.csv
# Converted BR037628290.dly to data/climate/ghcnd_all_csv/BR037628290.csv
# Converted ASN00016099.dly to data/climate/ghcnd_all_csv/ASN00016099.csv
# Converted GG000037539.dly to data/climate/ghcnd_all_csv/GG000037539.csv
# Converted IDM00097530.dly to data/climate/ghcnd_all_csv/IDM00097530.csv
# Converted CA008504050.dly to data/climate/ghcnd_all_csv/CA008504050.csv
# Converted FIE00142421.dly to data/climate/ghcnd_all_csv/FIE00142421.csv
# Converted ASN00078026.dly to data/climate/ghcnd_all_csv/ASN00078026.csv
# Converted CA007024080.dly to data/climate/ghcnd_all_csv/CA007024080.csv
# Converted RSM00022145.dly to data/climate/ghcnd_all_csv/RSM00022145.csv
# Converted CA1NS000205.dly to data/climate/ghcnd_all_csv/CA1NS000205.csv
# Converted ASN00067106.dly to data/climate/ghcnd_all_csv/ASN00067106.csv
# Converted IN006030700.dly to data/climate/ghcnd_all_csv/IN006030700.csv
# Converted ASN00009807.dly to data/climate/ghcnd_all_csv/ASN00009807.csv
# Converted HUM00012982.dly to data/climate/ghcnd_all_csv/HUM00012982.csv
# Converted RSM00034727.dly to data/climate/ghcnd_all_csv/RSM00034727.csv
# Converted ASN00085183.dly to data/climate/ghcnd_all_csv/ASN00085183.csv
# Converted NOE00134286.dly to data/climate/ghcnd_all_csv/NOE00134286.csv
# Converted CA001144388.dly to data/climate/ghcnd_all_csv/CA001144388.csv
# Converted BR00E2-0500.dly to data/climate/ghcnd_all_csv/BR00E2-0500.csv
# Converted ASN00023744.dly to data/climate/ghcnd_all_csv/ASN00023744.csv
# Converted NOE00110330.dly to data/climate/ghcnd_all_csv/NOE00110330.csv
# Converted ASN00035126.dly to data/climate/ghcnd_all_csv/ASN00035126.csv
# Converted BR00D5-0300.dly to data/climate/ghcnd_all_csv/BR00D5-0300.csv
# Converted ASN00088128.dly to data/climate/ghcnd_all_csv/ASN00088128.csv
# Converted ASN00097008.dly to data/climate/ghcnd_all_csv/ASN00097008.csv
# Converted GME00127042.dly to data/climate/ghcnd_all_csv/GME00127042.csv
# Converted ASN00012016.dly to data/climate/ghcnd_all_csv/ASN00012016.csv
# Converted ASN00054043.dly to data/climate/ghcnd_all_csv/ASN00054043.csv
# Converted MXN00011062.dly to data/climate/ghcnd_all_csv/MXN00011062.csv
# Converted CA002100515.dly to data/climate/ghcnd_all_csv/CA002100515.csv
# Converted ASN00099025.dly to data/climate/ghcnd_all_csv/ASN00099025.csv
# Converted CA006115389.dly to data/climate/ghcnd_all_csv/CA006115389.csv
# Converted ASN00086105.dly to data/climate/ghcnd_all_csv/ASN00086105.csv
# Converted CA006107955.dly to data/climate/ghcnd_all_csv/CA006107955.csv
# Converted ASN00010601.dly to data/climate/ghcnd_all_csv/ASN00010601.csv
# Converted ASN00041328.dly to data/climate/ghcnd_all_csv/ASN00041328.csv
# Converted BF1NP000001.dly to data/climate/ghcnd_all_csv/BF1NP000001.csv
# Converted ASN00040036.dly to data/climate/ghcnd_all_csv/ASN00040036.csv
# Converted CA006072460.dly to data/climate/ghcnd_all_csv/CA006072460.csv
# Converted ASN00029080.dly to data/climate/ghcnd_all_csv/ASN00029080.csv
# Converted CA002402687.dly to data/climate/ghcnd_all_csv/CA002402687.csv
# Converted ASN00006063.dly to data/climate/ghcnd_all_csv/ASN00006063.csv
# Converted BF1BY000001.dly to data/climate/ghcnd_all_csv/BF1BY000001.csv
# Converted ASN00039293.dly to data/climate/ghcnd_all_csv/ASN00039293.csv
# Converted CA003050779.dly to data/climate/ghcnd_all_csv/CA003050779.csv
# Converted IN017011500.dly to data/climate/ghcnd_all_csv/IN017011500.csv
# Converted ASN00084074.dly to data/climate/ghcnd_all_csv/ASN00084074.csv
# Converted CA1ON000674.dly to data/climate/ghcnd_all_csv/CA1ON000674.csv
# Converted ASN00040750.dly to data/climate/ghcnd_all_csv/ASN00040750.csv
# Converted ASN00010167.dly to data/climate/ghcnd_all_csv/ASN00010167.csv
# Converted ASN00056132.dly to data/climate/ghcnd_all_csv/ASN00056132.csv
# Converted IN020082100.dly to data/climate/ghcnd_all_csv/IN020082100.csv
# Converted CA001084351.dly to data/climate/ghcnd_all_csv/CA001084351.csv
# Converted ASN00049012.dly to data/climate/ghcnd_all_csv/ASN00049012.csv
# Converted ASN00072084.dly to data/climate/ghcnd_all_csv/ASN00072084.csv
# Converted CA007057287.dly to data/climate/ghcnd_all_csv/CA007057287.csv
# Converted BR038740540.dly to data/climate/ghcnd_all_csv/BR038740540.csv
# Converted GME00131146.dly to data/climate/ghcnd_all_csv/GME00131146.csv
# Converted CA003013132.dly to data/climate/ghcnd_all_csv/CA003013132.csv
# Converted BR047934210.dly to data/climate/ghcnd_all_csv/BR047934210.csv
# Converted MXN00008255.dly to data/climate/ghcnd_all_csv/MXN00008255.csv
# Converted GME00130258.dly to data/climate/ghcnd_all_csv/GME00130258.csv
# Converted ASN00063189.dly to data/climate/ghcnd_all_csv/ASN00063189.csv
# Converted MXN00007166.dly to data/climate/ghcnd_all_csv/MXN00007166.csv
# Converted MXN00028185.dly to data/climate/ghcnd_all_csv/MXN00028185.csv
# Converted CA003025480.dly to data/climate/ghcnd_all_csv/CA003025480.csv
# Converted BR00D8-0560.dly to data/climate/ghcnd_all_csv/BR00D8-0560.csv
# Converted IN019022300.dly to data/climate/ghcnd_all_csv/IN019022300.csv
# Converted ASN00090001.dly to data/climate/ghcnd_all_csv/ASN00090001.csv
# Converted CHM00055299.dly to data/climate/ghcnd_all_csv/CHM00055299.csv
# Converted ASN00072090.dly to data/climate/ghcnd_all_csv/ASN00072090.csv
# Converted ASN00004106.dly to data/climate/ghcnd_all_csv/ASN00004106.csv
# Converted ASN00081118.dly to data/climate/ghcnd_all_csv/ASN00081118.csv
# Converted EN000026242.dly to data/climate/ghcnd_all_csv/EN000026242.csv
# Converted MXN00008241.dly to data/climate/ghcnd_all_csv/MXN00008241.csv
# Converted CA003025494.dly to data/climate/ghcnd_all_csv/CA003025494.csv
# Converted MXN00028191.dly to data/climate/ghcnd_all_csv/MXN00028191.csv
# Converted MXN00007172.dly to data/climate/ghcnd_all_csv/MXN00007172.csv
# Converted IN017111500.dly to data/climate/ghcnd_all_csv/IN017111500.csv
# Converted MXN00018052.dly to data/climate/ghcnd_all_csv/MXN00018052.csv
# Converted ASN00090015.dly to data/climate/ghcnd_all_csv/ASN00090015.csv
# Converted KZ000035401.dly to data/climate/ghcnd_all_csv/KZ000035401.csv
# Converted ASN00084060.dly to data/climate/ghcnd_all_csv/ASN00084060.csv
# Converted CA006166415.dly to data/climate/ghcnd_all_csv/CA006166415.csv
# Converted BR038087250.dly to data/climate/ghcnd_all_csv/BR038087250.csv
# Converted GLE00146901.dly to data/climate/ghcnd_all_csv/GLE00146901.csv
# Converted GME00122890.dly to data/climate/ghcnd_all_csv/GME00122890.csv
# Converted CA001114742.dly to data/climate/ghcnd_all_csv/CA001114742.csv
# Converted BR038023280.dly to data/climate/ghcnd_all_csv/BR038023280.csv
# Converted ASN00056126.dly to data/climate/ghcnd_all_csv/ASN00056126.csv
# Converted ASN00010173.dly to data/climate/ghcnd_all_csv/ASN00010173.csv
# Converted MXN00012219.dly to data/climate/ghcnd_all_csv/MXN00012219.csv
# Converted ASN00049006.dly to data/climate/ghcnd_all_csv/ASN00049006.csv
# Converted BR00C7-0690.dly to data/climate/ghcnd_all_csv/BR00C7-0690.csv
# Converted CA001154400.dly to data/climate/ghcnd_all_csv/CA001154400.csv
# Converted MXN00015210.dly to data/climate/ghcnd_all_csv/MXN00015210.csv
# Converted CA005062337.dly to data/climate/ghcnd_all_csv/CA005062337.csv
# Converted RQ1PRLJ0002.dly to data/climate/ghcnd_all_csv/RQ1PRLJ0002.csv
# Converted MXN00005003.dly to data/climate/ghcnd_all_csv/MXN00005003.csv
# Converted ASN00010615.dly to data/climate/ghcnd_all_csv/ASN00010615.csv
# Converted BF1NP000015.dly to data/climate/ghcnd_all_csv/BF1NP000015.csv
# Converted CA1ON000106.dly to data/climate/ghcnd_all_csv/CA1ON000106.csv
# Converted BR002244037.dly to data/climate/ghcnd_all_csv/BR002244037.csv
# Converted ASN00083069.dly to data/climate/ghcnd_all_csv/ASN00083069.csv
# Converted ASN00006077.dly to data/climate/ghcnd_all_csv/ASN00006077.csv
# Converted ASN00029094.dly to data/climate/ghcnd_all_csv/ASN00029094.csv
# Converted ASN00040022.dly to data/climate/ghcnd_all_csv/ASN00040022.csv
# Converted SF000216550.dly to data/climate/ghcnd_all_csv/SF000216550.csv
# Converted CA005060520.dly to data/climate/ghcnd_all_csv/CA005060520.csv
# Converted CA001035940.dly to data/climate/ghcnd_all_csv/CA001035940.csv
# Converted ASN00054057.dly to data/climate/ghcnd_all_csv/ASN00054057.csv
# Converted ASN00012002.dly to data/climate/ghcnd_all_csv/ASN00012002.csv
# Converted CA006102839.dly to data/climate/ghcnd_all_csv/CA006102839.csv
# Converted ASN00075099.dly to data/climate/ghcnd_all_csv/ASN00075099.csv
# Converted CA1BC000099.dly to data/climate/ghcnd_all_csv/CA1BC000099.csv
# Converted MXN00011076.dly to data/climate/ghcnd_all_csv/MXN00011076.csv
# Converted CA003013640.dly to data/climate/ghcnd_all_csv/CA003013640.csv
# Converted BR001739021.dly to data/climate/ghcnd_all_csv/BR001739021.csv
# Converted CA006060070.dly to data/climate/ghcnd_all_csv/CA006060070.csv
# Converted ASN00086111.dly to data/climate/ghcnd_all_csv/ASN00086111.csv
# Converted ASN00051107.dly to data/climate/ghcnd_all_csv/ASN00051107.csv
# Converted CA00301C3D4.dly to data/climate/ghcnd_all_csv/CA00301C3D4.csv
# Converted MXN00015238.dly to data/climate/ghcnd_all_csv/MXN00015238.csv
# Converted CA001016169.dly to data/climate/ghcnd_all_csv/CA001016169.csv
# Converted ASN00041314.dly to data/climate/ghcnd_all_csv/ASN00041314.csv
# Converted CA006118849.dly to data/climate/ghcnd_all_csv/CA006118849.csv
# Converted ASN00008072.dly to data/climate/ghcnd_all_csv/ASN00008072.csv
# Converted RSM00025399.dly to data/climate/ghcnd_all_csv/RSM00025399.csv
# Converted ASN00083041.dly to data/climate/ghcnd_all_csv/ASN00083041.csv
# Converted BR00C7-0860.dly to data/climate/ghcnd_all_csv/BR00C7-0860.csv
# Converted MXN00014126.dly to data/climate/ghcnd_all_csv/MXN00014126.csv
# Converted ASN00088114.dly to data/climate/ghcnd_all_csv/ASN00088114.csv
# Converted MXN00030090.dly to data/climate/ghcnd_all_csv/MXN00030090.csv
# Converted ASN00097034.dly to data/climate/ghcnd_all_csv/ASN00097034.csv
# Converted ASN00099019.dly to data/climate/ghcnd_all_csv/ASN00099019.csv
# Converted IN018101800.dly to data/climate/ghcnd_all_csv/IN018101800.csv
# Converted ASN00086139.dly to data/climate/ghcnd_all_csv/ASN00086139.csv
# Converted CA006162883.dly to data/climate/ghcnd_all_csv/CA006162883.csv
# Converted MXN00016057.dly to data/climate/ghcnd_all_csv/MXN00016057.csv
# Converted ASN00091323.dly to data/climate/ghcnd_all_csv/ASN00091323.csv
# Converted GME00126406.dly to data/climate/ghcnd_all_csv/GME00126406.csv
# Converted MXN00026194.dly to data/climate/ghcnd_all_csv/MXN00026194.csv
# Converted CA003012210.dly to data/climate/ghcnd_all_csv/CA003012210.csv
# Converted BR00C4-0600.dly to data/climate/ghcnd_all_csv/BR00C4-0600.csv
# Converted MXN00008269.dly to data/climate/ghcnd_all_csv/MXN00008269.csv
# Converted ASN00053076.dly to data/climate/ghcnd_all_csv/ASN00053076.csv
# Converted RQW00011631.dly to data/climate/ghcnd_all_csv/RQW00011631.csv
# Converted BR002243016.dly to data/climate/ghcnd_all_csv/BR002243016.csv
# Converted ASN00084048.dly to data/climate/ghcnd_all_csv/ASN00084048.csv
# Converted IN001130200.dly to data/climate/ghcnd_all_csv/IN001130200.csv
# Converted BR002449006.dly to data/climate/ghcnd_all_csv/BR002449006.csv
# Converted ASN00047003.dly to data/climate/ghcnd_all_csv/ASN00047003.csv
# Converted ASN00031195.dly to data/climate/ghcnd_all_csv/ASN00031195.csv
# Converted ASN00058123.dly to data/climate/ghcnd_all_csv/ASN00058123.csv
# Converted BR028725940.dly to data/climate/ghcnd_all_csv/BR028725940.csv
# Converted ASN00041472.dly to data/climate/ghcnd_all_csv/ASN00041472.csv
# Converted MXN00012231.dly to data/climate/ghcnd_all_csv/MXN00012231.csv
# Converted CA001105667.dly to data/climate/ghcnd_all_csv/CA001105667.csv
# Converted MXN00002022.dly to data/climate/ghcnd_all_csv/MXN00002022.csv
# Converted IN011290300.dly to data/climate/ghcnd_all_csv/IN011290300.csv
# Converted BR002243002.dly to data/climate/ghcnd_all_csv/BR002243002.csv
# Converted IN014010400.dly to data/climate/ghcnd_all_csv/IN014010400.csv
# Converted ASN00047017.dly to data/climate/ghcnd_all_csv/ASN00047017.csv
# Converted CA008100200.dly to data/climate/ghcnd_all_csv/CA008100200.csv
# Converted ASN00058137.dly to data/climate/ghcnd_all_csv/ASN00058137.csv
# Converted CA004022360.dly to data/climate/ghcnd_all_csv/CA004022360.csv
# Converted ASN00040778.dly to data/climate/ghcnd_all_csv/ASN00040778.csv
# Converted ASN00031181.dly to data/climate/ghcnd_all_csv/ASN00031181.csv
# Converted MXN00012225.dly to data/climate/ghcnd_all_csv/MXN00012225.csv
# Converted ASN00041466.dly to data/climate/ghcnd_all_csv/ASN00041466.csv
# Converted BR038014410.dly to data/climate/ghcnd_all_csv/BR038014410.csv
# Converted GME00122674.dly to data/climate/ghcnd_all_csv/GME00122674.csv
# Converted MXN00002036.dly to data/climate/ghcnd_all_csv/MXN00002036.csv
# Converted ASN00091337.dly to data/climate/ghcnd_all_csv/ASN00091337.csv
# Converted MXN00016043.dly to data/climate/ghcnd_all_csv/MXN00016043.csv
# Converted KZ000038119.dly to data/climate/ghcnd_all_csv/KZ000038119.csv
# Converted ASN00081124.dly to data/climate/ghcnd_all_csv/ASN00081124.csv
# Converted MXN00026180.dly to data/climate/ghcnd_all_csv/MXN00026180.csv
# Converted CA003074181.dly to data/climate/ghcnd_all_csv/CA003074181.csv
# Converted GME00130270.dly to data/climate/ghcnd_all_csv/GME00130270.csv
# Converted ASN00090029.dly to data/climate/ghcnd_all_csv/ASN00090029.csv
# Converted BR000352004.dly to data/climate/ghcnd_all_csv/BR000352004.csv
# Converted ASN00053062.dly to data/climate/ghcnd_all_csv/ASN00053062.csv
# Converted BR00C6-0860.dly to data/climate/ghcnd_all_csv/BR00C6-0860.csv
# Converted ASN00088100.dly to data/climate/ghcnd_all_csv/ASN00088100.csv
# Converted CA008104700.dly to data/climate/ghcnd_all_csv/CA008104700.csv
# Converted MXN00030084.dly to data/climate/ghcnd_all_csv/MXN00030084.csv
# Converted ASN00097020.dly to data/climate/ghcnd_all_csv/ASN00097020.csv
# Converted IN001030200.dly to data/climate/ghcnd_all_csv/IN001030200.csv
# Converted NO000005350.dly to data/climate/ghcnd_all_csv/NO000005350.csv
# Converted IN011390300.dly to data/climate/ghcnd_all_csv/IN011390300.csv
# Converted MXN00021189.dly to data/climate/ghcnd_all_csv/MXN00021189.csv
# Converted ASN00051113.dly to data/climate/ghcnd_all_csv/ASN00051113.csv
# Converted CF000004452.dly to data/climate/ghcnd_all_csv/CF000004452.csv
# Converted BR00E6-0250.dly to data/climate/ghcnd_all_csv/BR00E6-0250.csv
# Converted BF1NP000029.dly to data/climate/ghcnd_all_csv/BF1NP000029.csv
# Converted ASN00041300.dly to data/climate/ghcnd_all_csv/ASN00041300.csv
# Converted ASN00008066.dly to data/climate/ghcnd_all_csv/ASN00008066.csv
# Converted ASN00010629.dly to data/climate/ghcnd_all_csv/ASN00010629.csv
# Converted IN023230500.dly to data/climate/ghcnd_all_csv/IN023230500.csv
# Converted CA008100566.dly to data/climate/ghcnd_all_csv/CA008100566.csv
# Converted BR000458000.dly to data/climate/ghcnd_all_csv/BR000458000.csv
# Converted CA006150825.dly to data/climate/ghcnd_all_csv/CA006150825.csv
# Converted ASN00083055.dly to data/climate/ghcnd_all_csv/ASN00083055.csv
# Converted CA004074640.dly to data/climate/ghcnd_all_csv/CA004074640.csv
# Converted BR00C5-0600.dly to data/climate/ghcnd_all_csv/BR00C5-0600.csv
# Converted MXN00014132.dly to data/climate/ghcnd_all_csv/MXN00014132.csv
# Converted NOE00112080.dly to data/climate/ghcnd_all_csv/NOE00112080.csv
# Converted CA00613659R.dly to data/climate/ghcnd_all_csv/CA00613659R.csv
# Converted ASN00029043.dly to data/climate/ghcnd_all_csv/ASN00029043.csv
# Converted ASN00036163.dly to data/climate/ghcnd_all_csv/ASN00036163.csv
# Converted CA007013360.dly to data/climate/ghcnd_all_csv/CA007013360.csv
# Converted IN023500101.dly to data/climate/ghcnd_all_csv/IN023500101.csv
# Converted BR00E3-1420.dly to data/climate/ghcnd_all_csv/BR00E3-1420.csv
# Converted IN009181000.dly to data/climate/ghcnd_all_csv/IN009181000.csv
# Converted ASN00039250.dly to data/climate/ghcnd_all_csv/ASN00039250.csv
# Converted IN019221100.dly to data/climate/ghcnd_all_csv/IN019221100.csv
# Converted CHM00056021.dly to data/climate/ghcnd_all_csv/CHM00056021.csv
# Converted CA001122541.dly to data/climate/ghcnd_all_csv/CA001122541.csv
# Converted BR038380550.dly to data/climate/ghcnd_all_csv/BR038380550.csv
# Converted CA008104933.dly to data/climate/ghcnd_all_csv/CA008104933.csv
# Converted BR002749041.dly to data/climate/ghcnd_all_csv/BR002749041.csv
# Converted RSM00028642.dly to data/climate/ghcnd_all_csv/RSM00028642.csv
# Converted ASN00024567.dly to data/climate/ghcnd_all_csv/ASN00024567.csv
# Converted MXN00021162.dly to data/climate/ghcnd_all_csv/MXN00021162.csv
# Converted BR057056640.dly to data/climate/ghcnd_all_csv/BR057056640.csv
# Converted CA001024642.dly to data/climate/ghcnd_all_csv/CA001024642.csv
# Converted IN020032600.dly to data/climate/ghcnd_all_csv/IN020032600.csv
# Converted MR000001498.dly to data/climate/ghcnd_all_csv/MR000001498.csv
# Converted ASN00054080.dly to data/climate/ghcnd_all_csv/ASN00054080.csv
# Converted CA008403501.dly to data/climate/ghcnd_all_csv/CA008403501.csv
# Converted MXN00008296.dly to data/climate/ghcnd_all_csv/MXN00008296.csv
# Converted MXN00028146.dly to data/climate/ghcnd_all_csv/MXN00028146.csv
# Converted MXN00018085.dly to data/climate/ghcnd_all_csv/MXN00018085.csv
# Converted ASN00053089.dly to data/climate/ghcnd_all_csv/ASN00053089.csv
# Converted BR003056007.dly to data/climate/ghcnd_all_csv/BR003056007.csv
# Converted CA003035650.dly to data/climate/ghcnd_all_csv/CA003035650.csv
# Converted IN003050400.dly to data/climate/ghcnd_all_csv/IN003050400.csv
# Converted RSM00037004.dly to data/climate/ghcnd_all_csv/RSM00037004.csv
# Converted ASN00034012.dly to data/climate/ghcnd_all_csv/ASN00034012.csv
# Converted ASN00072047.dly to data/climate/ghcnd_all_csv/ASN00072047.csv
# Converted CA006102150.dly to data/climate/ghcnd_all_csv/CA006102150.csv
# Converted RSM00027217.dly to data/climate/ghcnd_all_csv/RSM00027217.csv
# Converted CA002301102.dly to data/climate/ghcnd_all_csv/CA002301102.csv
# Converted IN024150200.dly to data/climate/ghcnd_all_csv/IN024150200.csv
# Converted RP000982230.dly to data/climate/ghcnd_all_csv/RP000982230.csv
# Converted ASN00066032.dly to data/climate/ghcnd_all_csv/ASN00066032.csv
# Converted BR002649055.dly to data/climate/ghcnd_all_csv/BR002649055.csv
# Converted BR001147001.dly to data/climate/ghcnd_all_csv/BR001147001.csv
# Converted MXN00023013.dly to data/climate/ghcnd_all_csv/MXN00023013.csv
# Converted AJ000037742.dly to data/climate/ghcnd_all_csv/AJ000037742.csv
# Converted BR002754010.dly to data/climate/ghcnd_all_csv/BR002754010.csv
# Converted GQC00914260.dly to data/climate/ghcnd_all_csv/GQC00914260.csv
# Converted RSM00025400.dly to data/climate/ghcnd_all_csv/RSM00025400.csv
# Converted ASN00040793.dly to data/climate/ghcnd_all_csv/ASN00040793.csv
# Converted FIE00143501.dly to data/climate/ghcnd_all_csv/FIE00143501.csv
# Converted ASN00079106.dly to data/climate/ghcnd_all_csv/ASN00079106.csv
# Converted ASN00066026.dly to data/climate/ghcnd_all_csv/ASN00066026.csv
# Converted IN020132600.dly to data/climate/ghcnd_all_csv/IN020132600.csv
# Converted MXN00023007.dly to data/climate/ghcnd_all_csv/MXN00023007.csv
# Converted BR002852050.dly to data/climate/ghcnd_all_csv/BR002852050.csv
# Converted AJ000037756.dly to data/climate/ghcnd_all_csv/AJ000037756.csv
# Converted MI000067689.dly to data/climate/ghcnd_all_csv/MI000067689.csv
# Converted CA006156515.dly to data/climate/ghcnd_all_csv/CA006156515.csv
# Converted CA004024936.dly to data/climate/ghcnd_all_csv/CA004024936.csv
# Converted BR00E2-1420.dly to data/climate/ghcnd_all_csv/BR00E2-1420.csv
# Converted IN009081000.dly to data/climate/ghcnd_all_csv/IN009081000.csv
# Converted CA001098977.dly to data/climate/ghcnd_all_csv/CA001098977.csv
# Converted BR000645002.dly to data/climate/ghcnd_all_csv/BR000645002.csv
# Converted NOE00111210.dly to data/climate/ghcnd_all_csv/NOE00111210.csv
# Converted CA005010762.dly to data/climate/ghcnd_all_csv/CA005010762.csv
# Converted ASN00072053.dly to data/climate/ghcnd_all_csv/ASN00072053.csv
# Converted ASN00034006.dly to data/climate/ghcnd_all_csv/ASN00034006.csv
# Converted CA006154302.dly to data/climate/ghcnd_all_csv/CA006154302.csv
# Converted IN024050200.dly to data/climate/ghcnd_all_csv/IN024050200.csv
# Converted GME00120922.dly to data/climate/ghcnd_all_csv/GME00120922.csv
# Converted ASN00024573.dly to data/climate/ghcnd_all_csv/ASN00024573.csv
# Converted CA004026847.dly to data/climate/ghcnd_all_csv/CA004026847.csv
# Converted CA003065715.dly to data/climate/ghcnd_all_csv/CA003065715.csv
# Converted CA003023740.dly to data/climate/ghcnd_all_csv/CA003023740.csv
# Converted MXN00021176.dly to data/climate/ghcnd_all_csv/MXN00021176.csv
# Converted ENE00175075.dly to data/climate/ghcnd_all_csv/ENE00175075.csv
# Converted CA006134390.dly to data/climate/ghcnd_all_csv/CA006134390.csv
# Converted BR001047001.dly to data/climate/ghcnd_all_csv/BR001047001.csv
# Converted ASN00054094.dly to data/climate/ghcnd_all_csv/ASN00054094.csv
# Converted CA004053200.dly to data/climate/ghcnd_all_csv/CA004053200.csv
# Converted ASN00029057.dly to data/climate/ghcnd_all_csv/ASN00029057.csv
# Converted RSM00025372.dly to data/climate/ghcnd_all_csv/RSM00025372.csv
# Converted ASN00070122.dly to data/climate/ghcnd_all_csv/ASN00070122.csv
# Converted IN019112200.dly to data/climate/ghcnd_all_csv/IN019112200.csv
# Converted ASN00039244.dly to data/climate/ghcnd_all_csv/ASN00039244.csv
# Converted NOE00105503.dly to data/climate/ghcnd_all_csv/NOE00105503.csv
# Converted FIE00145616.dly to data/climate/ghcnd_all_csv/FIE00145616.csv
# Converted CA007043543.dly to data/climate/ghcnd_all_csv/CA007043543.csv
# Converted CA008401302.dly to data/climate/ghcnd_all_csv/CA008401302.csv
# Converted BR038065570.dly to data/climate/ghcnd_all_csv/BR038065570.csv
# Converted ASN00008099.dly to data/climate/ghcnd_all_csv/ASN00008099.csv
# Converted BR00B6-0220.dly to data/climate/ghcnd_all_csv/BR00B6-0220.csv
# Converted BR00E2-0070.dly to data/climate/ghcnd_all_csv/BR00E2-0070.csv
# Converted CA1BC000072.dly to data/climate/ghcnd_all_csv/CA1BC000072.csv
# Converted ASN00075072.dly to data/climate/ghcnd_all_csv/ASN00075072.csv
# Converted ASN00033027.dly to data/climate/ghcnd_all_csv/ASN00033027.csv
# Converted IN001180500.dly to data/climate/ghcnd_all_csv/IN001180500.csv
# Converted CA007056600.dly to data/climate/ghcnd_all_csv/CA007056600.csv
# Converted MXN00030053.dly to data/climate/ghcnd_all_csv/MXN00030053.csv
# Converted AYW00088702.dly to data/climate/ghcnd_all_csv/AYW00088702.csv
# Converted MXN00024026.dly to data/climate/ghcnd_all_csv/MXN00024026.csv
# Converted BR000950002.dly to data/climate/ghcnd_all_csv/BR000950002.csv
# Converted FIE00142151.dly to data/climate/ghcnd_all_csv/FIE00142151.csv
# ...
# Converted BR001946008.dly to data/climate/ghcnd_all_csv/BR001946008.csv
# Converted CA003076566.dly to data/climate/ghcnd_all_csv/CA003076566.csv
# Converted IDM00096179.dly to data/climate/ghcnd_all_csv/IDM00096179.csv
# Converted ASN00040588.dly to data/climate/ghcnd_all_csv/ASN00040588.csv
# Converted CA003077678.dly to data/climate/ghcnd_all_csv/CA003077678.csv
# Converted BR002951024.dly to data/climate/ghcnd_all_csv/BR002951024.csv
# Converted ASN00078017.dly to data/climate/ghcnd_all_csv/ASN00078017.csv
# Converted PEM00084501.dly to data/climate/ghcnd_all_csv/PEM00084501.csv
# Converted ASN00068204.dly to data/climate/ghcnd_all_csv/ASN00068204.csv
# Converted ASN00009605.dly to data/climate/ghcnd_all_csv/ASN00009605.csv
# Converted IN019060300.dly to data/climate/ghcnd_all_csv/IN019060300.csv
# Converted BR000245011.dly to data/climate/ghcnd_all_csv/BR000245011.csv
# Converted ASN00040563.dly to data/climate/ghcnd_all_csv/ASN00040563.csv
# Converted ASN00094054.dly to data/climate/ghcnd_all_csv/ASN00094054.csv
# Converted IN001080900.dly to data/climate/ghcnd_all_csv/IN001080900.csv
# Converted MXN00003133.dly to data/climate/ghcnd_all_csv/MXN00003133.csv
# Converted ASN00046112.dly to data/climate/ghcnd_all_csv/ASN00046112.csv
# Converted IN012160700.dly to data/climate/ghcnd_all_csv/IN012160700.csv
# Converted ASN00085159.dly to data/climate/ghcnd_all_csv/ASN00085159.csv
# Converted NLE00152462.dly to data/climate/ghcnd_all_csv/NLE00152462.csv
# Converted ASN00059032.dly to data/climate/ghcnd_all_csv/ASN00059032.csv
# Converted ASN00030084.dly to data/climate/ghcnd_all_csv/ASN00030084.csv
# Converted BR027744920.dly to data/climate/ghcnd_all_csv/BR027744920.csv
# Converted BR027761550.dly to data/climate/ghcnd_all_csv/BR027761550.csv
# Converted ASN00014132.dly to data/climate/ghcnd_all_csv/ASN00014132.csv
# Converted RQ1PRRN0003.dly to data/climate/ghcnd_all_csv/RQ1PRRN0003.csv
# Converted CA001015109.dly to data/climate/ghcnd_all_csv/CA001015109.csv
# Converted MXN00016258.dly to data/climate/ghcnd_all_csv/MXN00016258.csv
# Converted CA00101HFNE.dly to data/climate/ghcnd_all_csv/CA00101HFNE.csv
# Converted FMW00040306.dly to data/climate/ghcnd_all_csv/FMW00040306.csv
# Converted MXN00008066.dly to data/climate/ghcnd_all_csv/MXN00008066.csv
# Converted MXN00027085.dly to data/climate/ghcnd_all_csv/MXN00027085.csv
# Converted NLE00109300.dly to data/climate/ghcnd_all_csv/NLE00109300.csv
# Converted RQC00668144.dly to data/climate/ghcnd_all_csv/RQC00668144.csv
# Converted CA008403097.dly to data/climate/ghcnd_all_csv/CA008403097.csv
# Converted ASN00080021.dly to data/climate/ghcnd_all_csv/ASN00080021.csv
# Converted MXN00007355.dly to data/climate/ghcnd_all_csv/MXN00007355.csv
# Converted BR00B4-0040.dly to data/climate/ghcnd_all_csv/BR00B4-0040.csv
# Converted ASN00012225.dly to data/climate/ghcnd_all_csv/ASN00012225.csv
# Converted CA003063180.dly to data/climate/ghcnd_all_csv/CA003063180.csv
# Converted ASN00087028.dly to data/climate/ghcnd_all_csv/ASN00087028.csv
# Converted CA1MB000121.dly to data/climate/ghcnd_all_csv/CA1MB000121.csv
# Converted CA00307NM9J.dly to data/climate/ghcnd_all_csv/CA00307NM9J.csv
# Converted ASN00044063.dly to data/climate/ghcnd_all_csv/ASN00044063.csv
# Converted ASN00002036.dly to data/climate/ghcnd_all_csv/ASN00002036.csv
# Converted ASN00014654.dly to data/climate/ghcnd_all_csv/ASN00014654.csv
# Converted ASN00086336.dly to data/climate/ghcnd_all_csv/ASN00086336.csv
# Converted CA008105605.dly to data/climate/ghcnd_all_csv/CA008105605.csv
# Converted GM000004204.dly to data/climate/ghcnd_all_csv/GM000004204.csv
# Converted ASN00089005.dly to data/climate/ghcnd_all_csv/ASN00089005.csv
# Converted RSM00029974.dly to data/climate/ghcnd_all_csv/RSM00029974.csv
# Converted BR00D7-0410.dly to data/climate/ghcnd_all_csv/BR00D7-0410.csv
# Converted CA003013467.dly to data/climate/ghcnd_all_csv/CA003013467.csv
# Converted KG000038483.dly to data/climate/ghcnd_all_csv/KG000038483.csv
# Converted PSC00914519.dly to data/climate/ghcnd_all_csv/PSC00914519.csv
# Converted IN011130301.dly to data/climate/ghcnd_all_csv/IN011130301.csv
# Converted MXN00015037.dly to data/climate/ghcnd_all_csv/MXN00015037.csv
# Converted AO000066447.dly to data/climate/ghcnd_all_csv/AO000066447.csv
# Converted MXN00014329.dly to data/climate/ghcnd_all_csv/MXN00014329.csv
# Converted BR002254003.dly to data/climate/ghcnd_all_csv/BR002254003.csv
# Converted ASN00016043.dly to data/climate/ghcnd_all_csv/ASN00016043.csv
# Converted ASN00050016.dly to data/climate/ghcnd_all_csv/ASN00050016.csv
# Converted ASN00009163.dly to data/climate/ghcnd_all_csv/ASN00009163.csv
# Converted CA1ON000321.dly to data/climate/ghcnd_all_csv/CA1ON000321.csv
# Converted IN020040700.dly to data/climate/ghcnd_all_csv/IN020040700.csv
# Converted IN023200800.dly to data/climate/ghcnd_all_csv/IN023200800.csv
# Converted CA001056742.dly to data/climate/ghcnd_all_csv/CA001056742.csv
# Converted ASN00040205.dly to data/climate/ghcnd_all_csv/ASN00040205.csv
# Converted MO000060265.dly to data/climate/ghcnd_all_csv/MO000060265.csv
# Converted ASN00082144.dly to data/climate/ghcnd_all_csv/ASN00082144.csv
# Converted ASN00008269.dly to data/climate/ghcnd_all_csv/ASN00008269.csv
# Converted CA0023026HN.dly to data/climate/ghcnd_all_csv/CA0023026HN.csv
# Converted GMM00010249.dly to data/climate/ghcnd_all_csv/GMM00010249.csv
# Converted ASN00037099.dly to data/climate/ghcnd_all_csv/ASN00037099.csv
# Converted MXN00015023.dly to data/climate/ghcnd_all_csv/MXN00015023.csv
# Converted IN004010501.dly to data/climate/ghcnd_all_csv/IN004010501.csv
# Converted ASN00093049.dly to data/climate/ghcnd_all_csv/ASN00093049.csv
# Converted ASN00050002.dly to data/climate/ghcnd_all_csv/ASN00050002.csv
# Converted ASN00016057.dly to data/climate/ghcnd_all_csv/ASN00016057.csv
# Converted CA1ON000335.dly to data/climate/ghcnd_all_csv/CA1ON000335.csv
# Converted ASN00009177.dly to data/climate/ghcnd_all_csv/ASN00009177.csv
# Converted CA007065012.dly to data/climate/ghcnd_all_csv/CA007065012.csv
# Converted ASN00040211.dly to data/climate/ghcnd_all_csv/ASN00040211.csv
# Converted ASN00012231.dly to data/climate/ghcnd_all_csv/ASN00012231.csv
# Converted IN018131500.dly to data/climate/ghcnd_all_csv/IN018131500.csv
# Converted ASN00002022.dly to data/climate/ghcnd_all_csv/ASN00002022.csv
# Converted MXN00020098.dly to data/climate/ghcnd_all_csv/MXN00020098.csv
# Converted ASN00044077.dly to data/climate/ghcnd_all_csv/ASN00044077.csv
# Converted ASN00014640.dly to data/climate/ghcnd_all_csv/ASN00014640.csv
# Converted ASN00089011.dly to data/climate/ghcnd_all_csv/ASN00089011.csv
# Converted EI000003965.dly to data/climate/ghcnd_all_csv/EI000003965.csv
# Converted IN009073700.dly to data/climate/ghcnd_all_csv/IN009073700.csv
# Converted CA0050410N0.dly to data/climate/ghcnd_all_csv/CA0050410N0.csv
# Converted GMW00035032.dly to data/climate/ghcnd_all_csv/GMW00035032.csv
# Converted IN012060700.dly to data/climate/ghcnd_all_csv/IN012060700.csv
# Converted KUM00040570.dly to data/climate/ghcnd_all_csv/KUM00040570.csv
# Converted KZ000038316.dly to data/climate/ghcnd_all_csv/KZ000038316.csv
# Converted ASN00091138.dly to data/climate/ghcnd_all_csv/ASN00091138.csv
# Converted BR028603550.dly to data/climate/ghcnd_all_csv/BR028603550.csv
# Converted IN023300800.dly to data/climate/ghcnd_all_csv/IN023300800.csv
# Converted MXN00027091.dly to data/climate/ghcnd_all_csv/MXN00027091.csv
# Converted CA006115810.dly to data/climate/ghcnd_all_csv/CA006115810.csv
# Converted MXN00008072.dly to data/climate/ghcnd_all_csv/MXN00008072.csv
# Converted ASN00080035.dly to data/climate/ghcnd_all_csv/ASN00080035.csv
# Converted CA008403083.dly to data/climate/ghcnd_all_csv/CA008403083.csv
# Converted CA1ON000453.dly to data/climate/ghcnd_all_csv/CA1ON000453.csv
# Converted ASN00009611.dly to data/climate/ghcnd_all_csv/ASN00009611.csv
# Converted ASN00094040.dly to data/climate/ghcnd_all_csv/ASN00094040.csv
# Converted MXN00099019.dly to data/climate/ghcnd_all_csv/MXN00099019.csv
# Converted ASN00040577.dly to data/climate/ghcnd_all_csv/ASN00040577.csv
# Converted BR00B5-0040.dly to data/climate/ghcnd_all_csv/BR00B5-0040.csv
# Converted BR048234060.dly to data/climate/ghcnd_all_csv/BR048234060.csv
# Converted IN007040100.dly to data/climate/ghcnd_all_csv/IN007040100.csv
# Converted ASN00046106.dly to data/climate/ghcnd_all_csv/ASN00046106.csv
# Converted NLE00152476.dly to data/climate/ghcnd_all_csv/NLE00152476.csv
# Converted BR00D6-0410.dly to data/climate/ghcnd_all_csv/BR00D6-0410.csv
# Converted BR000735067.dly to data/climate/ghcnd_all_csv/BR000735067.csv
# Converted GME00125314.dly to data/climate/ghcnd_all_csv/GME00125314.csv
# Converted ASN00030090.dly to data/climate/ghcnd_all_csv/ASN00030090.csv
# Converted RQC00665474.dly to data/climate/ghcnd_all_csv/RQC00665474.csv
# Converted ASN00059026.dly to data/climate/ghcnd_all_csv/ASN00059026.csv
# Converted IN011061600.dly to data/climate/ghcnd_all_csv/IN011061600.csv
# Converted ASN00091110.dly to data/climate/ghcnd_all_csv/ASN00091110.csv
# Converted MXN00016264.dly to data/climate/ghcnd_all_csv/MXN00016264.csv
# Converted GPM00078890.dly to data/climate/ghcnd_all_csv/GPM00078890.csv
# Converted AM000037954.dly to data/climate/ghcnd_all_csv/AM000037954.csv
# Converted CA001091235.dly to data/climate/ghcnd_all_csv/CA001091235.csv
# Converted RQC00668178.dly to data/climate/ghcnd_all_csv/RQC00668178.csv
# Converted MXN00007369.dly to data/climate/ghcnd_all_csv/MXN00007369.csv
# Converted ASN00005003.dly to data/climate/ghcnd_all_csv/ASN00005003.csv
# Converted IN001172200.dly to data/climate/ghcnd_all_csv/IN001172200.csv
# Converted ASN00043056.dly to data/climate/ghcnd_all_csv/ASN00043056.csv
# Converted BR047341520.dly to data/climate/ghcnd_all_csv/BR047341520.csv
# Converted MXN00099031.dly to data/climate/ghcnd_all_csv/MXN00099031.csv
# Converted ASN00094068.dly to data/climate/ghcnd_all_csv/ASN00094068.csv
# Converted ASN00057023.dly to data/climate/ghcnd_all_csv/ASN00057023.csv
# Converted ASN00009639.dly to data/climate/ghcnd_all_csv/ASN00009639.csv
# Converted ASN00048103.dly to data/climate/ghcnd_all_csv/ASN00048103.csv
# Converted ASN00085165.dly to data/climate/ghcnd_all_csv/ASN00085165.csv
# Converted BR003252001.dly to data/climate/ghcnd_all_csv/BR003252001.csv
# Converted CA005023170.dly to data/climate/ghcnd_all_csv/CA005023170.csv
# Converted ASN00007172.dly to data/climate/ghcnd_all_csv/ASN00007172.csv
# Converted BR047097860.dly to data/climate/ghcnd_all_csv/BR047097860.csv
# Converted ASN00041127.dly to data/climate/ghcnd_all_csv/ASN00041127.csv
# Converted CA001083157.dly to data/climate/ghcnd_all_csv/CA001083157.csv
# Converted CA1ON001003.dly to data/climate/ghcnd_all_csv/CA1ON001003.csv
# Converted CA001047673.dly to data/climate/ghcnd_all_csv/CA001047673.csv
# Converted ASN00018052.dly to data/climate/ghcnd_all_csv/ASN00018052.csv
# Converted BR001449003.dly to data/climate/ghcnd_all_csv/BR001449003.csv
# Converted BR002450002.dly to data/climate/ghcnd_all_csv/BR002450002.csv
# Converted IN005010600.dly to data/climate/ghcnd_all_csv/IN005010600.csv
# Converted GMM00010261.dly to data/climate/ghcnd_all_csv/GMM00010261.csv
# Converted BR002347057.dly to data/climate/ghcnd_all_csv/BR002347057.csv
# Converted BF1BI000002.dly to data/climate/ghcnd_all_csv/BF1BI000002.csv
# Converted BR00D6-1040.dly to data/climate/ghcnd_all_csv/BR00D6-1040.csv
# Converted MXN00014315.dly to data/climate/ghcnd_all_csv/MXN00014315.csv
# Converted CA00301S001.dly to data/climate/ghcnd_all_csv/CA00301S001.csv
# Converted ASN00093061.dly to data/climate/ghcnd_all_csv/ASN00093061.csv
# Converted CA001113550.dly to data/climate/ghcnd_all_csv/CA001113550.csv
# Converted ASN00040239.dly to data/climate/ghcnd_all_csv/ASN00040239.csv
# Converted ASN00012219.dly to data/climate/ghcnd_all_csv/ASN00012219.csv
# Converted BGM00041907.dly to data/climate/ghcnd_all_csv/BGM00041907.csv
# Converted CT000004605.dly to data/climate/ghcnd_all_csv/CT000004605.csv
# Converted MXN00010173.dly to data/climate/ghcnd_all_csv/MXN00010173.csv
# Converted JQW00021601.dly to data/climate/ghcnd_all_csv/JQW00021601.csv
# Converted IN019131601.dly to data/climate/ghcnd_all_csv/IN019131601.csv
# Converted ASN00087014.dly to data/climate/ghcnd_all_csv/ASN00087014.csv
# Converted ASN00089039.dly to data/climate/ghcnd_all_csv/ASN00089039.csv
# Converted FIE00141870.dly to data/climate/ghcnd_all_csv/FIE00141870.csv
# Converted ASN00065091.dly to data/climate/ghcnd_all_csv/ASN00065091.csv
# Converted CA001101154.dly to data/climate/ghcnd_all_csv/CA001101154.csv
# Converted ASN00055152.dly to data/climate/ghcnd_all_csv/ASN00055152.csv
# Converted BR00E2-0280.dly to data/climate/ghcnd_all_csv/BR00E2-0280.csv
# Converted CA006105395.dly to data/climate/ghcnd_all_csv/CA006105395.csv
# Converted ASN00074188.dly to data/climate/ghcnd_all_csv/ASN00074188.csv
# Converted ASN00015562.dly to data/climate/ghcnd_all_csv/ASN00015562.csv
# Converted CA1MB000109.dly to data/climate/ghcnd_all_csv/CA1MB000109.csv
# Converted ASN00087000.dly to data/climate/ghcnd_all_csv/ASN00087000.csv
# Converted BR038579610.dly to data/climate/ghcnd_all_csv/BR038579610.csv
# Converted FIE00141864.dly to data/climate/ghcnd_all_csv/FIE00141864.csv
# Converted CA001183631.dly to data/climate/ghcnd_all_csv/CA001183631.csv
# Converted ASN00065085.dly to data/climate/ghcnd_all_csv/ASN00065085.csv
# Converted BR038808460.dly to data/climate/ghcnd_all_csv/BR038808460.csv
# Converted ASN00055146.dly to data/climate/ghcnd_all_csv/ASN00055146.csv
# Converted CA001101140.dly to data/climate/ghcnd_all_csv/CA001101140.csv
# Converted GME00129274.dly to data/climate/ghcnd_all_csv/GME00129274.csv
# Converted ASN00041133.dly to data/climate/ghcnd_all_csv/ASN00041133.csv
# Converted ASN00007166.dly to data/climate/ghcnd_all_csv/ASN00007166.csv
# Converted CA006126558.dly to data/climate/ghcnd_all_csv/CA006126558.csv
# Converted ASN00008255.dly to data/climate/ghcnd_all_csv/ASN00008255.csv
# Converted NLE00155443.dly to data/climate/ghcnd_all_csv/NLE00155443.csv
# Converted NZM00093439.dly to data/climate/ghcnd_all_csv/NZM00093439.csv
# Converted ASN00018046.dly to data/climate/ghcnd_all_csv/ASN00018046.csv
# Converted MD000033885.dly to data/climate/ghcnd_all_csv/MD000033885.csv
# Converted ASN00039088.dly to data/climate/ghcnd_all_csv/ASN00039088.csv
# Converted MXN00014301.dly to data/climate/ghcnd_all_csv/MXN00014301.csv
# Converted GME00124750.dly to data/climate/ghcnd_all_csv/GME00124750.csv
# Converted MXN00099025.dly to data/climate/ghcnd_all_csv/MXN00099025.csv
# Converted ASN00057037.dly to data/climate/ghcnd_all_csv/ASN00057037.csv
# Converted ASN00048117.dly to data/climate/ghcnd_all_csv/ASN00048117.csv
# Converted ARM00087896.dly to data/climate/ghcnd_all_csv/ARM00087896.csv
# Converted ASN00085171.dly to data/climate/ghcnd_all_csv/ASN00085171.csv
# Converted BR00E3-0280.dly to data/climate/ghcnd_all_csv/BR00E3-0280.csv
# Converted MXN00012016.dly to data/climate/ghcnd_all_csv/MXN00012016.csv
# Converted ASN00007600.dly to data/climate/ghcnd_all_csv/ASN00007600.csv
# Converted NOE00134274.dly to data/climate/ghcnd_all_csv/NOE00134274.csv
# Converted AM000037798.dly to data/climate/ghcnd_all_csv/AM000037798.csv
# Converted IN003050800.dly to data/climate/ghcnd_all_csv/IN003050800.csv
# Converted MXN00006063.dly to data/climate/ghcnd_all_csv/MXN00006063.csv
# Converted CA007028890.dly to data/climate/ghcnd_all_csv/CA007028890.csv
# Converted CA006068145.dly to data/climate/ghcnd_all_csv/CA006068145.csv
# Converted IN005110600.dly to data/climate/ghcnd_all_csv/IN005110600.csv
# Converted BR002550002.dly to data/climate/ghcnd_all_csv/BR002550002.csv
# Converted IN004141000.dly to data/climate/ghcnd_all_csv/IN004141000.csv
# Converted BR001549003.dly to data/climate/ghcnd_all_csv/BR001549003.csv
# Converted ASN00091104.dly to data/climate/ghcnd_all_csv/ASN00091104.csv
# Converted MXN00019143.dly to data/climate/ghcnd_all_csv/MXN00019143.csv
# Converted CA001097888.dly to data/climate/ghcnd_all_csv/CA001097888.csv
# Converted ASN00080009.dly to data/climate/ghcnd_all_csv/ASN00080009.csv
# Converted NLE00109328.dly to data/climate/ghcnd_all_csv/NLE00109328.csv
# Converted ASN00043042.dly to data/climate/ghcnd_all_csv/ASN00043042.csv
# Converted ASN00005017.dly to data/climate/ghcnd_all_csv/ASN00005017.csv
